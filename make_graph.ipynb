# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = ['base', '(s0,t1)+(s1,t3)', '(s0,t0)+(s1,t3)', '(s0,t0)', '(s1,t3)',
'(s0,t2)+(s1,t3)']
y = [31.24, 30.41, 30.59, 31.30, 30.79, 30.63] # set14
y1 = [36.21, 34.29, 34.67, 35.96, 35.28, 34.80] # Manga109
y2 = [29.49, 27.62, 27.83, 29.49, 28.16, 27.91] # Urban

# %%
sns.set_theme(style="whitegrid")

ax = sns.barplot(x=x, y=y2)
plt.ylim(26, 30)
plt.xlabel('Loss + MSE(student, teacher)')
plt.ylabel('Average PSNR')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 20)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.1, height, ha = 'center', size = 9)

# %%
x = ['base', 'output_add']
y = [31.24, 31.28]
y1 = [36.21, 36.18]
y2 = [29.49, 29.56]

import pandas as pd

df = pd.DataFrame({'x' : ['base', 'base', 'base','output_add', 'output_add', 'output_add'],
'y' : [31.24, 36.21, 29.49, 31.28, 36.18, 29.56],
'dataset' : ['Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban']})

# %%
g = sns.catplot(x='dataset', y='y', hue='x', data=df, kind='bar')
ax = g.facet_axis(0, 0)
plt.ylim(28, 37)
plt.ylabel('Average PSNR')
plt.xlabel('Dataset')
for c in ax.containers:
    labels = [f'{(v.get_height()):.2f}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# %%
df = pd.DataFrame({'x' : ['base', 'base', 'base','Shallow', 'Shallow', 'Shallow','Reconstruct','Reconstruct','Reconstruct'],
'y' : [31.24, 36.21, 29.49, 31.21, 35.63, 29.56, 31.19, 35.93, 29.21],
'dataset' : ['Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban']})

# %%
g = sns.catplot(x='dataset', y='y', hue='x', data=df, kind='bar')
ax = g.facet_axis(0, 0)
plt.ylim(28, 37)
plt.ylabel('Average PSNR')
plt.xlabel('Dataset')
sns.set(font_scale=0.8)
for c in ax.containers:
    labels = [f'{(v.get_height()):.2f}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# %%
import pandas as pd

df = pd.DataFrame({'x' : ['base', 'base', 'base','K.D', 'K.D', 'K.D'],
'y' : [31.24, 36.21, 29.49, 31.32, 36.20, 29.58],
'dataset' : ['Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban']})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")
g = sns.catplot(x='dataset', y='y', hue='x', data=df, kind='bar')
ax = g.facet_axis(0, 0)
plt.ylim(28, 37)
plt.ylabel('Average PSNR')
plt.xlabel('Dataset')
for c in ax.containers:
    labels = [f'{(v.get_height()):.2f}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame({'x' : ['(1/3, 2/3)', '(1/3, 2/3)', '(1/3, 2/3)','(1/4, 2/4)', '(1/4, 2/4)','(1/4, 2/4)','(1/4, 3/4)','(1/4, 3/4)','(1/4, 3/4)','(2/4, 3/4)','(2/4, 3/4)','(2/4, 3/4)', '3layer', '3layer', '3layer'],
'y' : [31.28, 36.30, 29.52, 31.27, 36.41, 29.57, 31.26, 36.36, 29.49, 29.89, 32.97, 27.93, 31.30, 36.30, 29.62],
'dataset' : ['Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban' , 'Set14', 'Manga109', 'Urban']})

# %%
g = sns.catplot(x='dataset', y='y', hue='x', data=df, kind='bar')
ax = g.facet_axis(0, 0)
plt.ylim(26, 37)
plt.ylabel('Average PSNR')
plt.xlabel('Dataset')
sns.set(font_scale=1)
for c in ax.containers:
    labels = [f'{(v.get_height()):.2f}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge', rotation = 80, padding = 5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame({'x' : ['(1/3, 2/3)', '(1/3, 2/3)', '(1/3, 2/3)','(1/4, 2/4)', '(1/4, 2/4)','(1/4, 2/4)','(1/4, 3/4)','(1/4, 3/4)','(1/4, 3/4)','(2/4, 3/4)','(2/4, 3/4)','(2/4, 3/4)', '1layer', '1layer', '1layer'],
'y' : [30.50, 34.67, 27.74, 30.51, 34.69, 27.76, 30.47, 34.45, 27.71, 30.49, 34.60, 27.74, 32.00, 32.00, 32.00],
'dataset' : ['Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban' , 'Set14', 'Manga109', 'Urban']})

# %%
g = sns.catplot(x='dataset', y='y', hue='x', data=df, kind='bar')
ax = g.facet_axis(0, 0)
plt.ylim(26, 37)
plt.ylabel('Average PSNR')
plt.xlabel('Dataset')
sns.set(font_scale=1)
for c in ax.containers:
    labels = [f'{(v.get_height()):.2f}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge', rotation = 80, padding = 5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame({'x' : ['(1/3, 2/3)', '(1/3, 2/3)', '(1/3, 2/3)','(1/4, 2/4)', '(1/4, 2/4)','(1/4, 2/4)','(1/4, 3/4)','(1/4, 3/4)','(1/4, 3/4)','(2/4, 3/4)','(2/4, 3/4)','(2/4, 3/4)', 'teacher', 'teacher', 'teacher', 'student', 'student', 'student'],
'y' : [31.29, 36.17, 29.54, 31.28, 36.10, 29.51, 31.27, 36.11, 29.50, 31.27, 36.17, 29.52, 31.33, 36.29, 29.73, 32.00, 32.00, 32.00],
'dataset' : ['Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban' , 'Set14', 'Manga109', 'Urban', 'Set14', 'Manga109', 'Urban']})

# %%
g = sns.catplot(x='dataset', y='y', hue='x', data=df, kind='bar')
ax = g.facet_axis(0, 0)
plt.ylim(26, 37)
plt.ylabel('Average PSNR')
plt.xlabel('Dataset')
sns.set(font_scale=1)
for c in ax.containers:
    labels = [f'{(v.get_height()):.2f}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge', rotation = 80, padding = 5)
